# %%
import frameDiagnosticsBackend

# %%
#####################################################################
#Only these values need to be personalized

planet = 'WASP121b' #planet name
channels = ['ch1', 'ch2']         #Spitzer IRAC channel
AOR_snip = 'r6497'         #bit of AOR to pick out which folders contain AORs that should be analyzed
basepath = '/home/taylor/Documents/Research/spitzer/' #folder containing data to be analyzed
addStack = False        #do you want to add a correction stack to fix bad backgrounds
nsigma = 3 #How bad does a value need to be before you clip it

#####################################################################

# %%
for channel in channels:
    print('Analysing', channel)
    frameDiagnosticsBackend.run_diagnostics(planet, channel, AOR_snip, basepath, addStack, nsigma)
# Out:
# Analysing ch1
# Found the following AORs ['r64973568', 'r64974080', 'r64973056', 'r64975104']
# Analysing r64973568
# Analysing r64974080
# Analysing r64973056
# Analysing r64975104
# Ignore Frames: [0, 57]
# Bad by: [-24.23848779  -5.26358604] sigma
# Analysing ch2
# Found the following AORs ['r64974848', 'r64972544', 'r64974592', 'r64972288']
# Analysing r64974848
# Analysing r64972544
# Analysing r64974592
# Analysing r64972288
# Ignore Frames: [0]
# Bad by: [-8.0145897] sigma
