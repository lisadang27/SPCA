# %%
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing
from functools import partial

import frameDiagnosticsBackend
import photometryBackend

# %%
#####################################################################
#Only these values need to be personalized

# General parameters
planet = 'KELT16b' #planet name
channels = ['ch2']#'ch1',          #Spitzer IRAC channel
AOR_snip = 'r6766'         #bit of AOR to pick out which folders contain AORs that should be analyzed
basepath = '/home/taylor/Documents/Research/spitzer/' #folder containing data to be analyzed
addStacks = [False]        #do you want to add a correction stack to fix bad backgrounds
allowIgnoreFrames = [True, False] # do you want the frame diagnostics to automatically remove certain frames within a data cube?

# Frame Diagnostic parameters
nsigma = 3        #How bad does a value need to be before you clip it

# Photometry Options
subarray = True
maskStars = None
photometryMethod = 'Aperture'
radii = np.linspace(2.,6.,21,endpoint=True)
shape = 'Circular'
edges = ['Exact', 'Hard']
moveCentroids = [False, True]

# Best Photometry Options
highpassWidth = 5
trim = False # Trim data between some start and end point (good for bad starts or ends to data)
trimStart = 5.554285e4
trimEnd = 5.5544266e4

#####################################################################

# %%
for channel in channels:
    minRMSs = []
    phoptions = []
    
    for addStack in addStacks:
        print('Analysing', channel, 'for systematically bad frames...')
        ignoreFrames = frameDiagnosticsBackend.run_diagnostics(planet, channel, AOR_snip, basepath, addStack, nsigma)
    
        for allowIgnoreFrame in np.sort(allowIgnoreFrames)[::-1]:
            if allowIgnoreFrame:
                print('Using ignoreFrames')
            else:
                print('Overwriting ignoreFrames to []')
                ignoreFrames = []

            print('Trying the many different photometries...')
            pool = multiprocessing.Pool(4)
            for moveCentroid in moveCentroids:
                for edge in edges:
                    func = partial(photometryBackend.run_photometry, basepath, addStack, planet, channel, subarray, AOR_snip, ignoreFrames, maskStars, photometryMethod, shape, edge, moveCentroid)
                    pool.map(func, radii)
            pool.close()

            print('Selecting the best photometry method...')
            minRMS, phoption = photometryBackend.comparePhotometry(basepath, planet, channel, AOR_snip, ignoreFrames, addStack, highpassWidth, trim, trimStart, trimEnd)

            minRMSs.append(minRMS)
            phoptions.append(phoption)
    
    bestPhOption = phoptions[np.argmin(minRMSs)]
    
    print('The best overall photometry method is:')
    print(bestPhOption)
    print('With an RMS of:')
    print(str(np.round(np.min(minRMSs)*1e6,1)))
    
    with open(basepath+planet+'/analysis/'+channel+'/bestPhOption.txt', 'a') as file:
        file.write(bestPhOption+'\n')
        file.write(str(np.round(np.min(minRMSs)*1e6,1))+'\n\n')
# Out:
# Analysing ch2 for systematically bad frames...
# Found the following AORs ['r67668736', 'r67669248', 'r67666176', 'r67668480']
# Analysing r67668736
# Analysing r67669248
# Analysing r67666176
# Analysing r67668480
# Ignore Frames: [40, 59]
# Bad by: [ 3.29300525 -3.25858167] sigma
# Using ignoreFrames
# Trying the many different photometries...
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular3_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular3_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular3_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular4_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular3_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular4_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular4_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular4_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular3_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular5_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular5_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank
/home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/ignore/4umExactCircular2_4_movingCentroid
# Overwriting ignoreFrames to []
# Trying the many different photometries...
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular6_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular2_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular2_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular3_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular2_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular2_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular3_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular2_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular3_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular3_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular4_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular4_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular4_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular3_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular4_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular4_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular5_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular5_2
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular5_6
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular6_0
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular5_4
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umHardCircular5_8
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_8_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_0_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_2_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_4_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_6_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_0_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular2_2_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_4_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_6_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_0_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_4_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_8_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular3_8_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_2_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular4_6_movingCentroid
# Starting: /home/taylor/Documents/Research/spitzer/KELT16b/analysis/ch2/addedBlank/noIgnore/4umExactCircular5_0_movingCentroid
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-12:
# Traceback (most recent call last):
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/taylor/Documents/Research/spitzer/SPCA/notebooks/photometryBackend.py", line 108, in run_photometry
#     moveCentroid=moveCentroid)
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 729, in get_lightcurve
#     cx=xo_new, cy=yo_new, r=r, shape=shape, method=method, **kwargs)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 437, in A_photometry
#     tmp_sum.extend(phot_table['aperture_sum']*factor)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-37f999680c60> in <module>
#      19                 for edge in edges:
#      20                     func = partial(photometryBackend.run_photometry, basepath, addStack, planet, channel, subarray, AOR_snip, ignoreFrames, maskStars, photometryMethod, shape, edge, moveCentroid)
# ---> 21                     pool.map(func, radii)
#      22             pool.close()
#      23
#
# ~/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     286         in a list that is returned.
#     287         '''
# --> 288         return self._map_async(func, iterable, mapstar, chunksize).get()
#     289
#     290     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     662
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#     666             raise TimeoutError
#
# ~/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     659
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#     663     def get(self, timeout=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/python3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/home/taylor/Documents/Research/spitzer/SPCA/notebooks/photometryBackend.py", line 108, in run_photometry
#     moveCentroid=moveCentroid)
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 661, in get_lightcurve
#     w = WCS(hdu_list[0].header, naxis=[1,2])
# Traceback (most recent call last):
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/wcs/wcs.py", line 453, in __init__
#     sip = self._read_sip_kw(header, wcskey=key)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/wcs/wcs.py", line 1099, in _read_sip_kw
#     del header[key]
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/io/fits/header.py", line 234, in __delitem__
#     del self[idx]
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/io/fits/header.py", line 255, in __delitem__
#     self._updateindices(idx, increment=False)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/io/fits/header.py", line 1811, in _updateindices
#     for jdx, keyword_index in enumerate(indices):
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/taylor/Documents/Research/spitzer/SPCA/notebooks/photometryBackend.py", line 108, in run_photometry
#     moveCentroid=moveCentroid)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/photutils/aperture/photometry.py", line 243, in aperture_photometry
#     tbl['ycenter'] = xypos_pixel[1]
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 729, in get_lightcurve
#     cx=xo_new, cy=yo_new, r=r, shape=shape, method=method, **kwargs)
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 436, in A_photometry
#     phot_table = aperture_photometry(image_data[i,:,:], aperture, error=data_error, method=method)#, pixelwise_error=False)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/utils/decorators.py", line 521, in wrapper
#     return function(*args, **kwargs)
# KeyboardInterrupt
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/table/table.py", line 1426, in __setitem__
#     self.add_columns([new_column], copy=False)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/table/table.py", line 1805, in add_columns
#     newcols = list(self.columns.values())
# Traceback (most recent call last):
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/table/table.py", line 231, in values
#     return list(OrderedDict.values(self))
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/taylor/Documents/Research/spitzer/SPCA/notebooks/photometryBackend.py", line 108, in run_photometry
#     moveCentroid=moveCentroid)
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 657, in get_lightcurve
#     badframetable=badframetable, tossed=tossed)
#   File "/home/taylor/Documents/Research/spitzer/SPCA/Photometry_Aperture_TaylorVersion.py", line 172, in sigma_clipping
#     sig_clipped_data = sigma_clip(image_data2, sigma=sigma, iters=iters, cenfunc=np.ma.median, axis = 0)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/utils/decorators.py", line 521, in wrapper
#     return function(*args, **kwargs)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py", line 651, in sigma_clip
#     return_bounds=return_bounds, copy=copy)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py", line 474, in __call__
#     copy=copy)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py", line 367, in _sigmaclip_withaxis
#     self._compute_bounds(filtered_data, axis=axis)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py", line 271, in _compute_bounds
#     self._max_value = self.cenfunc(data, axis=axis)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/ma/extras.py", line 707, in median
#     keepdims=keepdims)
#   File "<__array_function__ internals>", line 6, in median
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 3502, in median
#     overwrite_input=overwrite_input)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 3410, in _ureduce
#     r = func(a, **kwargs)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 3556, in _median
#     return np.lib.utils._median_nancheck(part, rout, axis, out)
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/lib/utils.py", line 1164, in _median_nancheck
#     data = np.moveaxis(data, axis, -1)
#   File "<__array_function__ internals>", line 6, in moveaxis
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1393, in moveaxis
#     source = normalize_axis_tuple(source, a.ndim, 'source')
#   File "/home/taylor/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1319, in normalize_axis_tuple
#     axis = [operator.index(axis)]
# KeyboardInterrupt
